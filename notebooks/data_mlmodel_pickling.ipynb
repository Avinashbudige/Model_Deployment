# %% [markdown]
# # Libraries

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
import numpy as np
import os
import joblib
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Data

# %%
#loading the data
iris = load_iris()

# %%
#unpacking the data
X,y = iris['data'],iris['target']

# %%
X[0]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
y[0]
# Out:
# 0

# %%
#split
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %% [markdown]
# # Training

# %%
#training the data on RandomForestClassifier
model = RandomForestClassifier(n_estimators = 500)

# %% [markdown]
# # Model Creation

# %%
model = model.fit(x_train,y_train)

# %% [markdown]
# # Model Saving (Serialization)

# %%
#picking the trained model
pickle_filename = "finalized_model.sav"
joblib.dump(model,open(pickle_filename,"wb"))

# %%
data = np.array([5.1, 3.5, 1.4, 0.2]).reshape(-1, 1)

# %%
#loading and predicting the model 
loaded_model = joblib.load("finalized_model.sav")
loaded_model.score(x_test,y_test) #score
# Out:
# 0.9666666666666667
